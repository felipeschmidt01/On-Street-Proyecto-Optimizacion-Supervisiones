# %% [markdown]
# Optimización Asignación: Calendario Maestro

# %%
import pandas as pd
import collections
# DATOS A OBTENER

# -----------------------------------------------------------------------------
# 1. Datos "Maestros"
# -----------------------------------------------------------------------------

# Lista de Jefes de Operación - 97 elementos para calzarlo con clientes y móviles. 
# La idea es que cada sucursal móvil tenga un cliente y un jefe de operación asignado.
jefes_operacion = [
    "Álvaro Arancibia", # 1.
    "Cristobal Aniñir", # 2.
    "Cristobal Aniñir", # 3.
    "Cristobal Aniñir", # 4.
    "Cristobal Aniñir", # 5.
    "Cristobal Aniñir", # 6.
    "Cristobal Aniñir", # 7.
    "Cristobal Aniñir", # 8.
    "Cristobal Aniñir", # 9.
    "Cristobal Aniñir", # 10.
    "Cristobal Aniñir", # 11.
    "Cristobal Aniñir", # 12.
    "Cristobal Aniñir", # 13.
    "Cristobal Aniñir", # 14.
    "Cristobal Aniñir", # 15.
    "Cristobal Aniñir", # 16.
    "Cristobal Aniñir", # 17.
    "Cristobal Aniñir", # 18.
    "Cristobal Aniñir", # 19.
    "Cristobal Aniñir", # 20.
    "Cristobal Aniñir", # 21.
    "Cristobal Aniñir", # 22.
    "Cristobal Aniñir", # 23.
    "Cristobal Aniñir", # 24.
    "José Ocampos", # 25.
    "José Ocampos", # 26.
    "José Ocampos", # 27.
    "José Ocampos", # 28.
    "José Ocampos", # 29.
    "José Ocampos", # 30.
    "José Ocampos", # 31.
    "José Ocampos", # 32.
    "José Ocampos", # 33.
    "José Ocampos", # 34.
    "José Ocampos", # 35.
    "José Ocampos", # 36.
    "José Ocampos", # 37.
    "José Ocampos", # 38.
    "José Ocampos", # 39.
    "José Ocampos", # 40.
    "José Ocampos", # 41.
    "José Ocampos", # 42.
    "José Ocampos", # 43.
    "José Ocampos", # 44.
    "José Ocampos", # 45.
    "José Ocampos", # 46.
    "José Ocampos", # 47.
    "Ramón Vera", # 48.
    "Ramón Vera", # 49.
    "Ramón Vera", # 50.
    "Ramón Vera", # 51.
    "Ramón Vera", # 52.
    "Ramón Vera", # 53.
    "Ramón Vera", # 54.
    "Ramón Vera", # 55.
    "Ramón Vera", # 56.
    "Ramón Vera", # 57.
    "Ramón Vera", # 58.
    "Ramón Vera", # 59.
    "Ramón Vera", # 60.
    "Ramón Vera", # 61.
    "Sebastián Ibacache", # 62.
    "Sebastián Ibacache", # 63.
    "Sebastián Ibacache", # 64.
    "Sebastián Ibacache", # 65.
    "Sebastián Ibacache", # 66.
    "Sebastián Ibacache", # 67.
    "Sebastián Ibacache", # 68.
    "Sebastián Ibacache", # 69.
    "Sebastián Ibacache", # 70.
    "Sebastián Ibacache", # 71.
    "Sebastián Ibacache", # 72.
    "Sebastián Ibacache", # 73.
    "Sebastián Ibacache", # 74.
    "Sebastián Ibacache", # 75.
    "Sebastián Ibacache", # 76.
    "Sebastián Ibacache", # 77.
    "Sebastián Ibacache", # 78.
    "Sebastián Ibacache", # 79.
    "Sebastián Ibacache", # 80.
    "Sebastián Ibacache", # 81.
    "Valesca Cruzatt", # 82.
    "Valesca Cruzatt", # 83.
    "Valesca Cruzatt", # 84.
    "Valesca Cruzatt", # 85.
    "Valesca Cruzatt", # 86.
    "Valesca Cruzatt", # 87.
    "Valesca Cruzatt", # 88.
    "Valesca Cruzatt", # 89.
    "Valesca Cruzatt", # 90.
    "Valesca Cruzatt", # 91.
    "Valesca Cruzatt", # 92.
    "Valesca Cruzatt", # 93.
    "Valesca Cruzatt", # 94.
    "Valesca Cruzatt", # 95.
    "Valesca Cruzatt", # 96.
    "Valesca Cruzatt" # 97.
] # conjunto JO del modelo - índice "j"

# Lista de Clientes
clientes = [
    "Los Pelambres", # 1.
    "Habitat Móvil", # 2.
    "Habitat Móvil", # 3.
    "Habitat Móvil", # 4.
    "Habitat Móvil", # 5.
    "Habitat Móvil", # 6.
    "Caja 18", # 7.
    "Caja 18", # 8.
    "Caja 18", # 9.
    "La Araucana Móvil", # 10.
    "La Araucana Móvil", # 11.
    "La Araucana Móvil", # 12.
    "La Araucana Móvil", # 13.
    "La Araucana Móvil", # 14.
    "La Araucana Móvil", # 15.
    "La Araucana Móvil", # 16.
    "La Araucana Móvil", # 17.
    "La Araucana Móvil", # 18.
    "La Araucana Móvil", # 19.
    "La Araucana Móvil", # 20.
    "La Araucana Móvil", # 21.
    "La Araucana Móvil", # 22.
    "Punto Caja los Andes Móvil", # 23.
    "Punto Caja los Andes Móvil", # 24.
    "La Araucana Móvil", # 25.
    "CGE Móvil", # 26.
    "CGE Móvil", # 27.
    "Caja 18", # 28.
    "Caja 18", # 29.
    "Habitat Móvil", # 30.
    "Habitat Móvil", # 31.
    "Habitat Móvil", # 32.
    "La Araucana Móvil", # 33.
    "Habitat Móvil", # 34.
    "La Araucana Móvil", # 35.
    "La Araucana Móvil", # 36.
    "La Araucana Móvil", # 37.
    "La Araucana Móvil", # 38.
    "La Araucana Móvil", # 39.
    "La Araucana Móvil", # 40.
    "La Araucana Móvil", # 41.
    "La Araucana Móvil", # 42.
    "Punto Caja los Andes Móvil", # 43.
    "Punto Caja los Andes Móvil", # 44.
    "Punto Caja los Andes Móvil", # 45.
    "Caja 18", # 46.
    "CGE Móvil", # 47.
    "Lampa", # 48.
    "Lampa", # 49.
    "Lampa", # 50.
    "Lampa", # 51.
    "Naranjo y Asociados", # 52.
    "Habitat Móvil", # 53.
    "Habitat Móvil", # 54.
    "Habitat Móvil", # 55.
    "Habitat Móvil", # 56.
    "Habitat Móvil", # 57.
    "Habitat Móvil", # 58.
    "Habitat Móvil", # 59.
    "Habitat Móvil", # 60.
    "Fundación Acrux", # 61.
    "Mutual", # 62.
    "La Araucana Móvil", # 63.
    "La Araucana Móvil", # 64.
    "La Araucana Móvil", # 65.
    "La Araucana Móvil", # 66.
    "La Araucana Móvil", # 67.
    "La Araucana Móvil", # 68.
    "La Araucana Móvil", # 69.
    "La Araucana Móvil", # 70.
    "La Araucana Móvil", # 71.
    "La Araucana Móvil", # 72.
    "La Araucana Móvil", # 73.
    "La Araucana Móvil", # 74.
    "La Araucana Móvil", # 75.
    "La Araucana Móvil", # 76.
    "La Araucana Móvil", # 77.
    "La Araucana Móvil", # 78.
    "La Araucana Móvil", # 79.
    "La Araucana Móvil", # 80.
    "La Araucana Móvil", # 81.
    "CGE Móvil", # 82.
    "CGE Móvil", # 83.
    "Punto Caja los Andes Móvil", # 84.
    "Punto Caja los Andes Móvil", # 85.
    "Punto Caja los Andes Móvil", # 86.
    "Punto Caja los Andes Móvil", # 87.
    "Punto Caja los Andes Móvil", # 88.
    "Punto Caja los Andes Móvil", # 89.
    "Caja 18", # 90.
    "Caja 18", # 91.
    "Caja 18", # 92.
    "Caja 18", # 93.
    "Caja 18", # 94.
    "Caja 18", # 95.
    "Centinela" # 96.
]
 # conjunto C del modelo - índice "k"

# Lista de Móviles (97 registros)
moviles = [
    "Móvil", # 1.
    "Los Ángeles", # 2.
    "Osorno", # 3.
    "Puerto Montt", # 4.
    "Temuco", # 5.
    "Valdivia", # 6.
    "Temuco", # 7.
    "Osorno", # 8.
    "Puerto Montt", # 9.
    "Agencia Coyhaique", # 10.
    "Agencia Los Ángeles", # 11.
    "Agencia Temuco 1", # 12.
    "Agencia Temuco 2", # 13.
    "Agencia Temuco 3", # 14.
    "Agencia Valdivia", # 15.
    "Agencia Valdivia 2", # 16.
    "Promoción Castro", # 17.
    "Promoción Los Ángeles", # 18.
    "Promoción Puerto Montt", # 19.
    "Promoción Temuco 1", # 20.
    "Promoción Temuco 2", # 21.
    "Promoción Valdivia", # 22.
    "Ancud", # 23.
    "Panguipulli", # 24.
    "Agencia Coronel", # 25.
    "Maule", # 26.
    "Ñuble", # 27.
    "Rancagua 1", # 28.
    "Concepción", # 29.
    "Chillán", # 30.
    "Concepción 1", # 31.
    "Talca", # 32.
    "Agencia Chillán", # 33.
    "Concepción 2", # 34.
    "Agencia Concepción", # 35.
    "Agencia Curicó", # 36.
    "Agencia Linares", # 37.
    "Agencia San Carlos", # 38.
    "Promoción Chillán", # 39.
    "Promoción Concepción", # 40.
    "Promoción Linares", # 41.
    "Promoción Talca", # 42.
    "Cauquenes", # 43.
    "San Carlos", # 44.
    "San Clemente", # 45.
    "Rancagua 2", # 46.
    "O'Higgins", # 47.
    "Clínica Dental 1", # 48.
    "Clínica Dental 2", # 49.
    "Clínica General / Preventiva", # 50.
    "Clínica Ginecológica", # 51.
    "Calama", # 52.
    "5ta Costa", # 53.
    "Copiapó", # 54.
    "Iquique", # 55.
    "La Serena", # 56.
    "Quillota", # 57.
    "Rancagua", # 58.
    "Santiago 1", # 59.
    "Santiago 2", # 60.
    "Clínica Móvil", # 61.
    "Bus de capacitación", # 62.
    "Agencia Quillota", # 63.
    "Agencia San Bernardo", # 64.
    "Agencia San Fernando", # 65.
    "Agencia Talagante", # 66.
    "Agencia Viña del Mar", # 67.
    "Agencia San Antonio", # 68.
    "Promoción La Serena", # 69.
    "Promoción Maipú 1", # 70.
    "Promoción Maipú 2", # 71.
    "Promoción Maipú 3", # 72.
    "Promoción Maipú 4", # 73.
    "Promoción Merced 1", # 74.
    "Promoción Merced 2", # 75.
    "Promoción Merced 3", # 76.
    "Promoción Merced 4", # 77.
    "Promoción Quillota", # 78.
    "Promoción Rancagua", # 79.
    "Promoción San Fernando", # 80.
    "Promoción Viña del Mar", # 81.
    "Coquimbo", # 82.
    "RM", # 83.
    "Cabildo", # 84.
    "Limache", # 85.
    "Llay-Llay", # 86.
    "Los Vilos", # 87.
    "Taltal", # 88.
    "Tocopilla", # 89.
    "La Serena", # 90.
    "Valparaíso", # 91.
    "Viña del Mar", # 92.
    "RM 1", # 93.
    "RM 2", # 94.
    "RM 3", # 95.
    "RM 4", # 96.
    "Móvil" # 97.
]
 # conjunto M del modelo - índice "i"



# -----------------------------------------------------------------------------
# 2. Coordenadas de móviles y de jefes de operación
# -----------------------------------------------------------------------------

# A. Móviles
# Rellenamos esta lista con 97 tuplas (Latitud, Longitud).
# El orden debe ser exactamente el mismo que la lista 'moviles' de arriba.
coordenadas_moviles = [
    None, # 1. Móvil (Los Pelambres)
    None, # 2. Los Ángeles
    None, # 3. Osorno
    None, # 4. Puerto Montt
    None, # 5. Temuco
    None, # 6. Valdivia
    None, # 7. Temuco (Duplicado nombre, pero ubicación física puede ser distinta)
    None, # 8. Osorno
    None, # 9. Puerto Montt
    None, # 10. Agencia Coyhaique
    None, # 11. Agencia Los Ángeles
    None, # 12. Agencia Temuco 1
    None, # 13. Agencia Temuco 2
    None, # 14. Agencia Temuco 3
    None, # 15. Agencia Valdivia
    None, # 16. Agencia Valdivia 2
    None, # 17. Promoción Castro
    None, # 18. Promoción Los Ángeles
    None, # 19. Promoción Puerto Montt
    None, # 20. Promoción Temuco 1
    None, # 21. Promoción Temuco 2
    None, # 22. Promoción Valdivia
    None, # 23. Ancud
    None, # 24. Panguipulli
    None, # 25. Agencia Coronel
    None, # 26. Maule
    None, # 27. Ñuble
    None, # 28. Rancagua 1
    None, # 29. Concepción
    None, # 30. Chillán
    None, # 31. Concepción 1
    None, # 32. Talca
    None, # 33. Agencia Chillán
    None, # 34. Agencia Concepción
    None, # 35. Agencia Curicó
    None, # 36. Agencia Linares
    None, # 37. Agencia San Carlos
    None, # 38. Promoción Chillán
    None, # 39. Promoción Concepción
    None, # 40. Promoción Linares
    None, # 41. Promoción Talca
    None, # 42. Cauquenes
    None, # 43. San Carlos
    None, # 44. San Clemente
    None, # 45. Rancagua 2
    None, # 46. O'Higgins
    None, # 47. Clínica Dental 1
    None, # 48. Clínica Dental 2
    None, # 49. Clínica General / Preventiva
    None, # 50. Clínica Ginecológica
    None, # 51. Calama
    None, # 52. 5ta Costa
    None, # 53. Copiapó
    None, # 54. Iquique
    None, # 55. La Serena
    None, # 56. Quillota
    None, # 57. Rancagua
    None, # 58. Santiago 1
    None, # 59. Santiago 2
    None, # 60. Clínica Móvil
    None, # 61. Bus de capacitación
    None, # 62. Agencia Quillota
    None, # 63. Agencia San Bernardo
    None, # 64. Agencia San Fernando
    None, # 65. Agencia Talagante
    None, # 66. Agencia Viña del Mar
    None, # 67. Agencia San Antonio
    None, # 68. Promoción La Serena
    None, # 69. Promoción Maipú 1
    None, # 70. Promoción Maipú 2
    None, # 71. Promoción Maipú 3
    None, # 72. Promoción Maipú 4
    None, # 73. Promoción Merced 1
    None, # 74. Promoción Merced 2
    None, # 75. Promoción Merced 3
    None, # 76. Promoción Merced 4
    None, # 77. Promoción Quillota
    None, # 78. Promoción Rancagua
    None, # 79. Promoción San Fernando
    None, # 80. Promoción Viña del Mar
    None, # 81. Coquimbo
    None, # 82. RM
    None, # 83. Cabildo
    None, # 84. Limache
    None, # 85. Llay-Llay
    None, # 86. Los Vilos
    None, # 87. Taltal
    None, # 88. Tocopilla
    None, # 89. La Serena
    None, # 90. Valparaíso
    None, # 91. Viña del Mar
    None, # 92. RM 1
    None, # 93. RM 2
    None, # 94. RM 3
    None, # 95. RM 4
    None, # 96. Móvil (Caja 18)
    None  # 97. Móvil (Centinela)
]

# B. BASES DE LOS JEFES DE OPERACIÓN (Solo los únicos)
# Rellena con la coordenada BASE desde donde sale cada jefe.
bases_jefes_operacion = {
    "Álvaro Arancibia": None,    # Ej: "Santiago"
    "Cristobal Aniñir": None,    # Ej: "Temuco"
    "José Ocampos": None,        # Ej: "Concepción"
    "Ramón Vera": None,          # Ej: "Antofagasta"
    "Sebastián Ibacache": None,  # Ej: "Viña del Mar"
    "Valesca Cruzatt": None      # Ej: "La Serena"
}

# -----------------------------------------------------------------------------
# 3. Integración al Modelo (Mapeo Automático)
# -----------------------------------------------------------------------------

# Validación de longitud
if len(coordenadas_moviles) != len(moviles):
    print(f"¡ALERTA! Tienes {len(moviles)} móviles pero ingresaste {len(coordenadas_moviles)} coordenadas.")

# Crear Diccionario Final para el Modelo: Coordenadas_i
# Mapea cada móvil específico (por índice) a su coordenada
Coordenadas_i = {}
for idx, coord in enumerate(coordenadas_moviles):
    movil_nombre = moviles[idx]
    # Usamos una clave compuesta (Nombre + Índice) por si hay nombres repetidos como "Móvil"
    # Esto asegura que el "Móvil" de la fila 1 sea distinto al "Móvil" de la fila 97
    clave_unica = (movil_nombre, idx) 
    Coordenadas_i[clave_unica] = coord

print("Estructura de datos lista. Rellena los 'None' en la sección 2.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 93
#      82 # -----------------------------------------------------------------------------
#      83 # 2. Datos "Relacionales"
#      84 # -----------------------------------------------------------------------------
#      85
#      86 # Creamos un DataFrame para visualizar y manipular fácilmente
#      87 data = {
#      88     "Jefe": jefes_operacion,
#      89     "Cliente": clientes,
#      90     "Movil": moviles
#      91 }
# ---> 93 df_asignaciones = pd.DataFrame(data)
#      95 # Verificación rápida de integridad
#      96 assert len(jefes_operacion) == len(clientes) == len(moviles), "Error: Las listas tienen longitudes distintas"
#
# File c:\Users\mfsch\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# File c:\Users\mfsch\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\mfsch\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\mfsch\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
moviles = [
    "Móvil", # 1.
    "Los Ángeles", # 2.
    "Osorno", # 3.
    "Puerto Montt", # 4.
    "Temuco", # 5.
    "Valdivia", # 6.
    "Temuco", # 7.
    "Osorno", # 8.
    "Puerto Montt", # 9.
    "Agencia Coyhaique", # 10.
    "Agencia Los Ángeles", # 11.
    "Agencia Temuco 1", # 12.
    "Agencia Temuco 2", # 13.
    "Agencia Temuco 3", # 14.
    "Agencia Valdivia", # 15.
    "Agencia Valdivia 2", # 16.
    "Promoción Castro", # 17.
    "Promoción Los Ángeles", # 18.
    "Promoción Puerto Montt", # 19.
    "Promoción Temuco 1", # 20.
    "Promoción Temuco 2", # 21.
    "Promoción Valdivia", # 22.
    "Ancud", # 23.
    "Panguipulli", # 24.
    "Agencia Coronel", # 25.
    "Maule", # 26.
    "Ñuble", # 27.
    "Rancagua 1", # 28.
    "Concepción", # 29.
    "Chillán", # 30.
    "Concepción 1", # 31.
    "Talca", # 32.
    "Agencia Chillán", # 33.
    "Concepción 2", # 34.
    "Agencia Concepción", # 35.
    "Agencia Curicó", # 36.
    "Agencia Linares", # 37.
    "Agencia San Carlos", # 38.
    "Promoción Chillán", # 39.
    "Promoción Concepción", # 40.
    "Promoción Linares", # 41.
    "Promoción Talca", # 42.
    "Cauquenes", # 43.
    "San Carlos", # 44.
    "San Clemente", # 45.
    "Rancagua 2", # 46.
    "O'Higgins", # 47.
    "Clínica Dental 1", # 48.
    "Clínica Dental 2", # 49.
    "Clínica General / Preventiva", # 50.
    "Clínica Ginecológica", # 51.
    "Calama", # 52.
    "5ta Costa", # 53.
    "Copiapó", # 54.
    "Iquique", # 55.
    "La Serena", # 56.
    "Quillota", # 57.
    "Rancagua", # 58.
    "Santiago 1", # 59.
    "Santiago 2", # 60.
    "Clínica Móvil", # 61.
    "Bus de capacitación", # 62.
    "Agencia Quillota", # 63.
    "Agencia San Bernardo", # 64.
    "Agencia San Fernando", # 65.
    "Agencia Talagante", # 66.
    "Agencia Viña del Mar", # 67.
    "Agencia San Antonio", # 68.
    "Promoción La Serena", # 69.
    "Promoción Maipú 1", # 70.
    "Promoción Maipú 2", # 71.
    "Promoción Maipú 3", # 72.
    "Promoción Maipú 4", # 73.
    "Promoción Merced 1", # 74.
    "Promoción Merced 2", # 75.
    "Promoción Merced 3", # 76.
    "Promoción Merced 4", # 77.
    "Promoción Quillota", # 78.
    "Promoción Rancagua", # 79.
    "Promoción San Fernando", # 80.
    "Promoción Viña del Mar", # 81.
    "Coquimbo", # 82.
    "RM", # 83.
    "Cabildo", # 84.
    "Limache", # 85.
    "Llay-Llay", # 86.
    "Los Vilos", # 87.
    "Taltal", # 88.
    "Tocopilla", # 89.
    "La Serena", # 90.
    "Valparaíso", # 91.
    "Viña del Mar", # 92.
    "RM 1", # 93.
    "RM 2", # 94.
    "RM 3", # 95.
    "RM 4", # 96.
    "Móvil" # 97.
]
len(moviles)
# Out:
# 96

# %%
coordenadas_moviles = [
    None, # 1. Móvil (Los Pelambres)
    None, # 2. Los Ángeles
    None, # 3. Osorno
    None, # 4. Puerto Montt
    None, # 5. Temuco
    None, # 6. Valdivia
    None, # 7. Temuco (Duplicado nombre, pero ubicación física puede ser distinta)
    None, # 8. Osorno
    None, # 9. Puerto Montt
    None, # 10. Agencia Coyhaique
    None, # 11. Agencia Los Ángeles
    None, # 12. Agencia Temuco 1
    None, # 13. Agencia Temuco 2
    None, # 14. Agencia Temuco 3
    None, # 15. Agencia Valdivia
    None, # 16. Agencia Valdivia 2
    None, # 17. Promoción Castro
    None, # 18. Promoción Los Ángeles
    None, # 19. Promoción Puerto Montt
    None, # 20. Promoción Temuco 1
    None, # 21. Promoción Temuco 2
    None, # 22. Promoción Valdivia
    None, # 23. Ancud
    None, # 24. Panguipulli
    None, # 25. Agencia Coronel
    None, # 26. Maule
    None, # 27. Ñuble
    None, # 28. Rancagua 1
    None, # 29. Concepción
    None, # 30. Chillán
    None, # 31. Concepción 1
    None, # 32. Talca
    None, # 33. Agencia Chillán
    None, # 34. Agencia Concepción
    None, # 35. Agencia Curicó
    None, # 36. Agencia Linares
    None, # 37. Agencia San Carlos
    None, # 38. Promoción Chillán
    None, # 39. Promoción Concepción
    None, # 40. Promoción Linares
    None, # 41. Promoción Talca
    None, # 42. Cauquenes
    None, # 43. San Carlos
    None, # 44. San Clemente
    None, # 45. Rancagua 2
    None, # 46. O'Higgins
    None, # 47. Clínica Dental 1
    None, # 48. Clínica Dental 2
    None, # 49. Clínica General / Preventiva
    None, # 50. Clínica Ginecológica
    None, # 51. Calama
    None, # 52. 5ta Costa
    None, # 53. Copiapó
    None, # 54. Iquique
    None, # 55. La Serena
    None, # 56. Quillota
    None, # 57. Rancagua
    None, # 58. Santiago 1
    None, # 59. Santiago 2
    None, # 60. Clínica Móvil
    None, # 61. Bus de capacitación
    None, # 62. Agencia Quillota
    None, # 63. Agencia San Bernardo
    None, # 64. Agencia San Fernando
    None, # 65. Agencia Talagante
    None, # 66. Agencia Viña del Mar
    None, # 67. Agencia San Antonio
    None, # 68. Promoción La Serena
    None, # 69. Promoción Maipú 1
    None, # 70. Promoción Maipú 2
    None, # 71. Promoción Maipú 3
    None, # 72. Promoción Maipú 4
    None, # 73. Promoción Merced 1
    None, # 74. Promoción Merced 2
    None, # 75. Promoción Merced 3
    None, # 76. Promoción Merced 4
    None, # 77. Promoción Quillota
    None, # 78. Promoción Rancagua
    None, # 79. Promoción San Fernando
    None, # 80. Promoción Viña del Mar
    None, # 81. Coquimbo
    None, # 82. RM
    None, # 83. Cabildo
    None, # 84. Limache
    None, # 85. Llay-Llay
    None, # 86. Los Vilos
    None, # 87. Taltal
    None, # 88. Tocopilla
    None, # 89. La Serena
    None, # 90. Valparaíso
    None, # 91. Viña del Mar
    None, # 92. RM 1
    None, # 93. RM 2
    None, # 94. RM 3
    None, # 95. RM 4
    None, # 96. Móvil (Caja 18)
    None  # 97. Móvil (Centinela)
]

len(coordenadas_moviles)
# Out:
# 97
